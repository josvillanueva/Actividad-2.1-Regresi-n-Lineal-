# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from turtle import color
#from funpymodeling.exploratory import freq_tbl

# %%
df = pd.read_csv("Wuppi_limpio.csv")
df
# Out:
#       Unnamed: 0 Administrador       Usuario  botón correcto  \
# 0              0       nicolas       nicolas             1.0
# 1              1       nicolas       nicolas             0.0
# 2              2       nicolas       nicolas             1.0
# 3              3       nicolas       nicolas             0.0
# 4              4       nicolas       nicolas             0.0
# ...          ...           ...           ...             ...
# 5860        5860        ALEIDA     ESMERALDA            99.0
# 5861        5861        ALEIDA  JOSE JAVIER              0.0
# 5862        5862        ALEIDA  JOSE JAVIER             99.0
# 5863        5863        ALEIDA  JOSE JAVIER             99.0
# 5864        5864        ALEIDA  JOSE JAVIER             99.0
#
#       tiempo de interacción  mini juego  número de interacción  \
# 0                  5.399169    Despegue                    1.0
# 1                  1.283400    Despegue                    2.0
# ...

# %%
df.drop(columns=["Unnamed: 0"])
# Out:
#      Administrador       Usuario  botón correcto  tiempo de interacción  \
# 0          nicolas       nicolas             1.0               5.399169
# 1          nicolas       nicolas             0.0               1.283400
# 2          nicolas       nicolas             1.0               2.700226
# 3          nicolas       nicolas             0.0               3.050262
# 4          nicolas       nicolas             0.0               4.750256
# ...            ...           ...             ...                    ...
# 5860        ALEIDA     ESMERALDA            99.0              99.000000
# 5861        ALEIDA  JOSE JAVIER              0.0               2.135419
# 5862        ALEIDA  JOSE JAVIER             99.0              99.000000
# 5863        ALEIDA  JOSE JAVIER             99.0              99.000000
# 5864        ALEIDA  JOSE JAVIER             99.0              99.000000
#
#       mini juego  número de interacción color presionado  dificultad  \
# ...

# %%
valores_nulos_cols = df.isnull().sum()
valores_nulos_cols
# Out:
# Unnamed: 0               0
# Administrador            0
# Usuario                  0
# botón correcto           0
# tiempo de interacción    0
# mini juego               0
# número de interacción    0
# color presionado         0
# dificultad               0
# fecha                    0
# Juego                    0
# auto push                0
# tiempo de lección        0
# tiempo de sesión         0
# dtype: int64

# %% [markdown]
# ### Pasar variables ordinales a numericas según la frecuencia más alta ###

# %% [markdown]
# ### Administardor ###

# %%
df1 = df.groupby(["Administrador"])["Administrador"].count()
df1
# Out:
# Administrador
# ALEIDA            3260
# AUSTIN             199
# BENJAMIN            51
# CARLOS ENRIQUE     228
# DENISSE            302
# IKER BENJAMIN      128
# KYTZIA              98
# LEONARDO           371
# SERGIO ANGEL       243
# VALENTIN           163
# YAEL DAVID         224
# erick              158
# nicolas            440
# Name: Administrador, dtype: int64

# %%
df["Administrador"]= df["Administrador"].replace({"ALEIDA":"1"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"nicolas":"2"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"LEONARDO":"3"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"DENISSE":"4"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"SERGIO ANGEL":"5"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"CARLOS ENRIQUE":"6"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"YAEL DAVID":"7"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"AUSTIN":"8"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"VALENTIN":"9"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"erick":"10"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"IKER BENJAMIN":"11"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"KYTZIA":"12"}, regex=False)
df["Administrador"]= df["Administrador"].replace({"BENJAMIN":"13"}, regex=False)

# %%
df1 = df.groupby(["Administrador"])["Administrador"].count()
df1
# Out:
# Administrador
# 1     3260
# 10     158
# 11     128
# 12      98
# 13      51
# 2      440
# 3      371
# 4      302
# 5      243
# 6      228
# 7      224
# 8      199
# 9      163
# Name: Administrador, dtype: int64

# %%
df["Administrador"]=df["Administrador"].astype(float)

# %% [markdown]
# ### Usuario ###

# %%
df1 = df.groupby(["Usuario"])["Usuario"].count()
df1
# Out:
# Usuario
# ADRIAN                280
# ALEIDA                487
# ARLETT                 29
# ASHLEY                 75
# AUSTIN                 96
# BENJAMIN               51
# CARLOS ABEL            39
# CARLOS ENRIQUE        228
# CONCEPCION            103
# DENISSE               228
# ERICK OSVALDO         126
# ESMERALDA              24
# IKER BENJAMIN         152
# INGRID                 49
# IRVING                 10
# JESUS ALEJANDRO       356
# JOSE IAN               86
# JOSE IGNACIO TADEO     94
# JOSE JAVIER           394
# JOSHUA                 74
# KYTZIA                 98
# LEONARDO              371
# LEONARDO              546
# MA DEL ROSARIO         64
# NICOLAS |             128
# RENE                   44
# SERGIO ANGEL          243
# VALENTIN              163
# YAEL DAVID            224
# YEREMI YAZMIN          71
# erick                 158
# jesus eduardo           2
# nicolas               440
# ramiro isai           332
# Name: Usuario, dtype: int64

# %%
df["Usuario"]= df["Usuario"].replace({"LEONARDO ":"1"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ALEIDA":"2"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"nicolas":"3"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"JOSE JAVIER ":"4"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"LEONARDO":"1"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"JESUS ALEJANDRO":"5"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ramiro isai":"6"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ADRIAN ":"7"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"SERGIO ANGEL":"8"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"DENISSE":"9"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"CARLOS ENRIQUE":"10"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"YAEL DAVID":"11"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"VALENTIN":"12"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"erick ":"13"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"IKER BENJAMIN":"14"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"NICOLAS |":"3"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ERICK OSVALDO":"15"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"CONCEPCION":"16"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"KYTZIA":"17"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"AUSTIN":"18"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"JOSE IGNACIO TADEO":"19"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"JOSE IAN":"20"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ASHLEY ":"21"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"JOSHUA":"22"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"YEREMI YAZMIN ":"23"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"MA DEL ROSARIO ":"24"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"BENJAMIN":"25"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"INGRID":"26"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"RENE ":"27"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"CARLOS ABEL":"28"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ARLETT":"29"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"ESMERALDA":"30"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"IRVING ":"31"}, regex=False)
df["Usuario"]= df["Usuario"].replace({"jesus eduardo":"32"}, regex=False)

# %%
df1 = df.groupby(["Usuario"])["Usuario"].count()
df1
# Out:
# Usuario
# 1     917
# 10    228
# 11    224
# 12    163
# 13    158
# 14    152
# 15    126
# 16    103
# 17     98
# 18     96
# 19     94
# 2     487
# 20     86
# 21     75
# 22     74
# 23     71
# 24     64
# 25     51
# 26     49
# 27     44
# 28     39
# 29     29
# 3     568
# 30     24
# 31     10
# 32      2
# 4     394
# 5     356
# 6     332
# 7     280
# 8     243
# 9     228
# Name: Usuario, dtype: int64

# %%
df["Usuario"]=df["Usuario"].astype(float)

# %% [markdown]
# ### Mini juego ###

# %%
df1 = df.groupby(["mini juego"])["mini juego"].count()
df1
# Out:
# mini juego
# 99                     156
# Asteroides            1054
# Despegue               196
# Estrellas              813
# Gusanos                748
# MiniGame_0               8
# MiniGame_1               3
# MiniGame_2               5
# MiniGame_3               5
# Restaurante            869
# animales y colores     545
# figuras y colores      400
# partes del cuerpo      320
# sonidos y animales     743
# Name: mini juego, dtype: int64

# %%
df["mini juego"]= df["mini juego"].replace({"Asteroides":"1"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"Restaurante":"2"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"Estrellas":"3"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"Gusanos":"4"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"sonidos y animales":"5"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"animales y colores":"6"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"figuras y colores":"7"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"partes del cuerpo":"8"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"Despegue":"9"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"MiniGame_0":"10"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"MiniGame_1":"11"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"MiniGame_2":"12"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"MiniGame_3":"13"}, regex=False)
df["mini juego"]= df["mini juego"].replace({"99":"99"}, regex=False)

# %%
df1 = df.groupby(["mini juego"])["mini juego"].count()
df1
# Out:
# mini juego
# 1     1054
# 10       8
# 11       3
# 12       5
# 13       5
# 2      869
# 3      813
# 4      748
# 5      743
# 6      545
# 7      400
# 8      320
# 9      196
# 99     156
# Name: mini juego, dtype: int64

# %%
df["mini juego"]=df["mini juego"].astype(float)

# %% [markdown]
# ### Color presionado ###

# %%
df1 = df.groupby(["color presionado"])["color presionado"].count()
df1
# Out:
# color presionado
# 99         762
# blue      1182
# green     1298
# red         29
# violet    1361
# yellow    1233
# Name: color presionado, dtype: int64

# %%
df["color presionado"]= df["color presionado"].replace({"violet":"1"}, regex=False)
df["color presionado"]= df["color presionado"].replace({"green":"2"}, regex=False)
df["color presionado"]= df["color presionado"].replace({"yellow":"3"}, regex=False)
df["color presionado"]= df["color presionado"].replace({"blue":"4"}, regex=False)
df["color presionado"]= df["color presionado"].replace({"red":"5"}, regex=False)
df["color presionado"]= df["color presionado"].replace({"99":"99"}, regex=False)

# %%
df1 = df.groupby(["color presionado"])["color presionado"].count()
df1
# Out:
# color presionado
# 1     1361
# 2     1298
# 3     1233
# 4     1182
# 5       29
# 99     762
# Name: color presionado, dtype: int64

# %%
df["color presionado"]=df["color presionado"].astype(float)

# %% [markdown]
# ### Dificultad ###

# %%
df5 = df.groupby(["dificultad"])["dificultad"].count()
df5
# Out:
# dificultad
# Episodio 1    2357
# Episodio 2    1493
# Episodio 3    1292
# Episodio 4     723
# Name: dificultad, dtype: int64

# %%
df["dificultad"]= df["dificultad"].replace({"Episodio 1":"1"}, regex=False)
df["dificultad"]= df["dificultad"].replace({"Episodio 2":"2"}, regex=False)
df["dificultad"]= df["dificultad"].replace({"Episodio 3":"3"}, regex=False)
df["dificultad"]= df["dificultad"].replace({"Episodio 4":"4"}, regex=False)

# %%
df5 = df.groupby(["dificultad"])["dificultad"].count()
df5
# Out:
# dificultad
# 1    2357
# 2    1493
# 3    1292
# 4     723
# Name: dificultad, dtype: int64

# %%
df["dificultad"]=df["dificultad"].astype(float)

# %% [markdown]
# ### Juego ###

# %%
df6 = df.groupby(["Juego"])["Juego"].count()
df6
# Out:
# Juego
# Astro      3799
# Cadetes    2066
# Name: Juego, dtype: int64

# %%
df["Juego"]= df["Juego"].replace({"Astro":"1"}, regex=False)
df["Juego"]= df["Juego"].replace({"Cadetes":"2"}, regex=False)

# %%
df6 = df.groupby(["Juego"])["Juego"].count()
df6
# Out:
# Juego
# 1    3799
# 2    2066
# Name: Juego, dtype: int64

# %%
df["Juego"]=df["Juego"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5865 entries, 0 to 5864
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5865 non-null   int64
#  1   Administrador          5865 non-null   float64
#  2   Usuario                5865 non-null   float64
#  3   botón correcto         5865 non-null   float64
#  4   tiempo de interacción  5865 non-null   float64
#  5   mini juego             5865 non-null   float64
#  6   número de interacción  5865 non-null   float64
#  7   color presionado       5865 non-null   float64
#  8   dificultad             5865 non-null   float64
#  9   fecha                  5865 non-null   object
#  10  Juego                  5865 non-null   float64
#  11  auto push              5865 non-null   float64
#  12  tiempo de lección      5865 non-null   float64
#  13  tiempo de sesión       5865 non-null   float64
# ...

# %%
df
# Out:
#       Unnamed: 0  Administrador  Usuario  botón correcto  \
# 0              0            2.0      3.0             1.0
# 1              1            2.0      3.0             0.0
# 2              2            2.0      3.0             1.0
# 3              3            2.0      3.0             0.0
# 4              4            2.0      3.0             0.0
# ...          ...            ...      ...             ...
# 5860        5860            1.0     30.0            99.0
# 5861        5861            1.0      4.0             0.0
# 5862        5862            1.0      4.0            99.0
# 5863        5863            1.0      4.0            99.0
# 5864        5864            1.0      4.0            99.0
#
#       tiempo de interacción  mini juego  número de interacción  \
# 0                  5.399169         9.0                    1.0
# 1                  1.283400         9.0                    2.0
# 2                  2.700226         9.0                    3.0
# ...

# %%
df = df.drop(columns=["Unnamed: 0",'fecha'])

# %% [markdown]
# ### Heat map  variable usuario como objetivo###

# %%
sns.pairplot(df)

# %%
Corr_Factors =df.corr()
Corr_Factors
# Out:
#                        Administrador   Usuario  botón correcto  \
# Administrador               1.000000  0.367783        0.057388
# Usuario                     0.367783  1.000000        0.089893
# botón correcto              0.057388  0.089893        1.000000
# tiempo de interacción       0.023198  0.079054        0.903912
# mini juego                  0.006635  0.087822        0.434521
# número de interacción      -0.080123 -0.099914        0.691533
# color presionado            0.055421  0.088253        0.999374
# dificultad                 -0.099609 -0.100570        0.026733
# Juego                       0.080074  0.350478        0.031036
# auto push                  -0.004080  0.123459       -0.035770
# tiempo de lección           0.044328  0.071091        0.612377
# tiempo de sesión            0.020546  0.023883        0.277868
#
#                        tiempo de interacción  mini juego  \
# Administrador                       0.023198    0.006635
# ...

# %%
Corr_Factors1 = abs(Corr_Factors)
Corr_Factors1
# Out:
#                        Administrador   Usuario  botón correcto  \
# Administrador               1.000000  0.367783        0.057388
# Usuario                     0.367783  1.000000        0.089893
# botón correcto              0.057388  0.089893        1.000000
# tiempo de interacción       0.023198  0.079054        0.903912
# mini juego                  0.006635  0.087822        0.434521
# número de interacción       0.080123  0.099914        0.691533
# color presionado            0.055421  0.088253        0.999374
# dificultad                  0.099609  0.100570        0.026733
# Juego                       0.080074  0.350478        0.031036
# auto push                   0.004080  0.123459        0.035770
# tiempo de lección           0.044328  0.071091        0.612377
# tiempo de sesión            0.020546  0.023883        0.277868
#
#                        tiempo de interacción  mini juego  \
# Administrador                       0.023198    0.006635
# ...

# %%
#ajustar al coeficiente de correlacion 
Heat_Map = sns.heatmap(Corr_Factors1, cmap="Purples", annot=True, fmt=".2f")

# %% [markdown]
# ### Modelo de regresion simple ###

# %%
sns.scatterplot(x="Juego", y="Usuario", color = "blue", data=df)
# Out:
# <Axes: xlabel='Juego', ylabel='Usuario'>

# %%
Vars_Indep= df[['Juego']]
Var_Dep= df['Usuario']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_DeterS=model.score(Vars_Indep,Var_Dep)
coef_DeterS
# Out:
# 0.12283515754211238

# %%
#Coeficiente de correlacion
coef_CorrelS=np.sqrt(coef_DeterS)
coef_CorrelS
# Out:
# np.float64(0.3504784694415798)

# %% [markdown]
# ## Modelo de regresion multiple ##

# %%
sns.scatterplot(x='Juego', y='Usuario', color="blue", data=df)
sns.scatterplot(x='número de interacción', y='Usuario', color="red", data=df)
sns.scatterplot(x='botón correcto', y='Usuario', color="yellow", data=df)
# Out:
# <Axes: xlabel='Juego', ylabel='Usuario'>

# %%
Vars_Indep= df[['Juego', 'número de interacción','botón correcto']]
Var_Dep= df['Usuario']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter=model.score(Vars_Indep,Var_Dep)
coef_Deter
# Out:
# 0.15891171123791037

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.3986373179193217)

# %% [markdown]
# ## Data Frame por usuario ## (LEONARDO(1) , MA DEL ROSARIO(24), NICOLAS (3), RENE (27), SERGIO ANGEL(8))

# %% [markdown]
# ## Leonardo ##

# %%
#leornardo (1)
df_filtrado1 = df[df['Usuario'] == 1]  
df_filtrado1
# Out:
#       Administrador  Usuario  botón correcto  tiempo de interacción  \
# 179             3.0      1.0             1.0              10.558070
# 180             3.0      1.0             0.0               1.249828
# 181             3.0      1.0             1.0               1.866516
# 182             3.0      1.0             0.0              10.099820
# 183             3.0      1.0             0.0              17.817100
# ...             ...      ...             ...                    ...
# 4867            1.0      1.0             0.0               3.650664
# 4868            1.0      1.0             0.0               3.916507
# 4869            1.0      1.0            99.0              99.000000
# 4870            1.0      1.0            99.0              99.000000
# 4871            1.0      1.0            99.0              99.000000
#
#       mini juego  número de interacción  color presionado  dificultad  Juego  \
# ...

# %%
df_filtrado1.isnull().sum()
# Out:
# Administrador            0
# Usuario                  0
# botón correcto           0
# tiempo de interacción    0
# mini juego               0
# número de interacción    0
# color presionado         0
# dificultad               0
# Juego                    0
# auto push                0
# tiempo de lección        0
# tiempo de sesión         0
# dtype: int64

# %%
sns.pairplot(df_filtrado1)

# %%
Corr_Factors1 =df_filtrado1.corr()
Corr_Factors1
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador               1.000000      NaN        0.219028
# Usuario                          NaN      NaN             NaN
# botón correcto              0.219028      NaN        1.000000
# tiempo de interacción      -0.034486      NaN        0.731554
# mini juego                  0.127578      NaN        0.465786
# número de interacción      -0.365267      NaN        0.221510
# color presionado            0.216252      NaN        0.999082
# dificultad                  0.202905      NaN        0.189427
# Juego                       0.390477      NaN        0.088227
# auto push                        NaN      NaN             NaN
# tiempo de lección           0.132274      NaN        0.574275
# tiempo de sesión            0.064751      NaN        0.297817
#
#                        tiempo de interacción  mini juego  \
# Administrador                      -0.034486    0.127578
# ...

# %%
Corr_Factors12 = abs(Corr_Factors1)
Corr_Factors12
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador               1.000000      NaN        0.219028
# Usuario                          NaN      NaN             NaN
# botón correcto              0.219028      NaN        1.000000
# tiempo de interacción       0.034486      NaN        0.731554
# mini juego                  0.127578      NaN        0.465786
# número de interacción       0.365267      NaN        0.221510
# color presionado            0.216252      NaN        0.999082
# dificultad                  0.202905      NaN        0.189427
# Juego                       0.390477      NaN        0.088227
# auto push                        NaN      NaN             NaN
# tiempo de lección           0.132274      NaN        0.574275
# tiempo de sesión            0.064751      NaN        0.297817
#
#                        tiempo de interacción  mini juego  \
# Administrador                       0.034486    0.127578
# ...

# %%
#ajustar al coeficiente de correlacion 
Heat_Map = sns.heatmap(Corr_Factors12, cmap="Purples", annot=True, fmt=".2f")

# %% [markdown]
# ### Modelo de regresion simple ##

# %%
sns.scatterplot(x="color presionado", y="tiempo de interacción", color = "blue", data=df_filtrado1)
# Out:
# <Axes: xlabel='color presionado', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado1[['color presionado']]
Var_Dep= df_filtrado1['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Leonardo=model.score(Vars_Indep,Var_Dep)
coef_Deter_Leonardo
# Out:
# 0.522752304516322

# %%
coef_Correl_Leonardo=np.sqrt(coef_Deter_Leonardo)
coef_Correl_Leonardo
# Out:
# np.float64(0.7230161163600173)

# %% [markdown]
# ### Modelo de regresion multiple ###

# %%
sns.scatterplot(x='botón correcto', y='tiempo de interacción', color="blue", data=df_filtrado1)
sns.scatterplot(x='número de interacción', y='tiempo de interacción', color="red", data=df_filtrado1)
sns.scatterplot(x='color presionado', y='tiempo de interacción', color="yellow", data=df_filtrado1)
# Out:
# <Axes: xlabel='botón correcto', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado1[['botón correcto', 'número de interacción','color presionado']]
Var_Dep= df_filtrado1['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Leonardo=model.score(Vars_Indep,Var_Dep)
coef_Deter_Leonardo
# Out:
# 0.899249276638887

# %%
coef_Correl_Leonardo=np.sqrt(coef_Deter_Leonardo)
coef_Correl_Leonardo
# Out:
# np.float64(0.9482875495538718)

# %%
#Predecimos los valores de total de boton correcto a partir de las variables: 'número de interacción', 'tiempo de interacción','tiempo de lección'
y_pred= model.predict(X=df_filtrado1[['botón correcto', 'número de interacción','color presionado']])
y_pred
# Out:
# array([ 3.32157992,  3.73942312,  2.30062156,  1.90492735,  2.20798559,
#         4.02333368,  2.69931709, 99.05841409,  1.69450509,  1.29881088,
#         1.48708415,  3.41721721,  2.90673803, 99.05841409,  3.32157992,
#         3.73942312,  3.11415897,  1.79014239,  3.021523  ,  3.32458124,
#         3.5128545 , 99.05841409,  1.69450509,  3.62463815,  3.22894394,
#         1.79014239,  3.72027544, 99.05841409,  1.69450509,  3.73942312,
#         4.04248135,  4.34553959,  4.64859783,  4.95165606,  5.2547143 ,
#         5.44298756,  4.93250839,  4.53681418,  4.72508744, 99.05841409,
#         1.69450509,  1.18402592,  3.11415897,  2.6036798 ,  4.53381286,
#        99.05841409,  3.43636488,  3.62463815,  3.11415897,  1.90492735,
#         2.09320062,  2.51104383,  3.5128545 ,  3.1171603 ,  3.42021853,
#         3.6084918 , 99.05841409,  1.69450509,  3.62463815,  1.48708415,
#         3.41721721,  2.09320062, 99.05841409,  1.69450509,  1.29881088,
# ...

# %%
df_filtrado1.insert(3, 'Predicciones', y_pred)
df_filtrado1
# Out:
#       Administrador  Usuario  botón correcto  Predicciones  \
# 179             3.0      1.0             1.0      3.321580
# 180             3.0      1.0             0.0      3.739423
# 181             3.0      1.0             1.0      2.300622
# 182             3.0      1.0             0.0      1.904927
# 183             3.0      1.0             0.0      2.207986
# ...             ...      ...             ...           ...
# 4867            1.0      1.0             0.0     12.113270
# 4868            1.0      1.0             0.0     13.229866
# 4869            1.0      1.0            99.0     99.058414
# 4870            1.0      1.0            99.0     99.058414
# 4871            1.0      1.0            99.0     99.058414
#
#       tiempo de interacción  mini juego  número de interacción  \
# 179               10.558070         9.0                    1.0
# 180                1.249828         9.0                    2.0
# 181                1.866516         9.0                    3.0
# ...

# %% [markdown]
# ## MA del Rosario ##

# %%
#MA del rosario
df_filtrado2 = df[df['Usuario'] == 24]  
df_filtrado2
# Out:
#       Administrador  Usuario  botón correcto  tiempo de interacción  \
# 5713            1.0     24.0             1.0              19.303690
# 5714            1.0     24.0             1.0               6.267806
# 5715            1.0     24.0             1.0               5.766922
# 5716            1.0     24.0             0.0               7.450372
# 5717            1.0     24.0             0.0               7.564992
# ...             ...      ...             ...                    ...
# 5772            1.0     24.0             1.0               2.782771
# 5773            1.0     24.0             1.0               2.316111
# 5774            1.0     24.0             1.0               3.616160
# 5775            1.0     24.0            99.0              99.000000
# 5776            1.0     24.0            99.0              99.000000
#
#       mini juego  número de interacción  color presionado  dificultad  Juego  \
# ...

# %%
sns.pairplot(df_filtrado2)

# %%
Corr_Factors2 =df_filtrado2.corr()
Corr_Factors2
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.993117
# mini juego                       NaN      NaN        0.662648
# número de interacción            NaN      NaN        0.998162
# color presionado                 NaN      NaN        0.999520
# dificultad                       NaN      NaN       -0.022086
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.579607
# tiempo de sesión                 NaN      NaN        0.625791
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Corr_Factors22 = abs(Corr_Factors2)
Corr_Factors22
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.993117
# mini juego                       NaN      NaN        0.662648
# número de interacción            NaN      NaN        0.998162
# color presionado                 NaN      NaN        0.999520
# dificultad                       NaN      NaN        0.022086
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.579607
# tiempo de sesión                 NaN      NaN        0.625791
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Heat_Map = sns.heatmap(Corr_Factors22, cmap="Greys", annot=True, fmt=".2f")

# %% [markdown]
# ### Modelo de regresion simple ###

# %%
sns.scatterplot(x="color presionado", y="tiempo de interacción", color = "blue", data=df_filtrado2)
# Out:
# <Axes: xlabel='color presionado', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado2[['color presionado']]
Var_Dep= df_filtrado2['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Ma_Del_Rosario=model.score(Vars_Indep,Var_Dep)
coef_Deter_Ma_Del_Rosario
# Out:
# 0.986480456906192

# %%
coef_Correl_Ma_Del_Rosario=np.sqrt(coef_Deter_Ma_Del_Rosario)
coef_Correl_Ma_Del_Rosario
# Out:
# np.float64(0.9932172254377146)

# %% [markdown]
# ### Modelo de regresion multiple ###

# %%
sns.scatterplot(x='botón correcto', y='tiempo de interacción', color="blue", data=df_filtrado2)
sns.scatterplot(x='número de interacción', y='tiempo de interacción', color="red", data=df_filtrado2)
sns.scatterplot(x='color presionado', y='tiempo de interacción', color="yellow", data=df_filtrado2)
# Out:
# <Axes: xlabel='botón correcto', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado2[['botón correcto', 'número de interacción','color presionado']]
Var_Dep= df_filtrado2['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Ma_Del_Rosario=model.score(Vars_Indep,Var_Dep)
coef_Deter_Ma_Del_Rosario
# Out:
# 0.9869989145568099

# %%
coef_Correl_Ma_Del_Rosario=np.sqrt(coef_Deter_Ma_Del_Rosario)
coef_Correl_Ma_Del_Rosario
# Out:
# np.float64(0.9934781902773758)

# %%
#Predecimos los valores de total de boton correcto a partir de las variables: 'número de interacción', 'tiempo de interacción','tiempo de lección'
y_pred= model.predict(X=df_filtrado2[['botón correcto', 'número de interacción','color presionado']])
y_pred
# Out:
# array([ 8.80212756,  6.76657646,  6.45482875,  7.19189017,  6.88014246,
#         7.24338899, 98.98739511, 98.98739511,  6.40332993,  6.09158221,
#         5.7798345 ,  5.46808679,  5.83133332,  5.99379362,  6.35704015,
#         4.89609019,  4.58434247, 98.98739511, 98.98739511,  7.07832417,
#         7.91577872,  6.45482875,  7.29228329, 98.98739511, 98.98739511,
#         8.80212756,  7.91577872,  5.7798345 ,  7.29228329,  6.40593445,
#         6.66878786, 98.98739511, 98.98739511,  8.80212756,  7.34117759,
#         6.92903675,  7.86688442,  7.5551367 ,  6.66878786, 98.98739511,
#        98.98739511,  8.22752643,  7.91577872,  8.17863213,  6.14308104,
#         5.83133332,  7.24338899,  5.78243903, 98.98739511, 98.98739511,
#         8.12713331,  7.81538559,  7.50363788,  7.19189017,  6.88014246,
#         6.56839474,  6.25664703,  6.61989357,  4.58434247,  4.84719589,
#         4.53544817,  5.37290272, 98.98739511, 98.98739511])

# %%
df_filtrado2.insert(3, 'Predicciones', y_pred)
df_filtrado2
# Out:
#       Administrador  Usuario  botón correcto  Predicciones  \
# 5713            1.0     24.0             1.0      8.802128
# 5714            1.0     24.0             1.0      6.766576
# 5715            1.0     24.0             1.0      6.454829
# 5716            1.0     24.0             0.0      7.191890
# 5717            1.0     24.0             0.0      6.880142
# ...             ...      ...             ...           ...
# 5772            1.0     24.0             1.0      4.847196
# 5773            1.0     24.0             1.0      4.535448
# 5774            1.0     24.0             1.0      5.372903
# 5775            1.0     24.0            99.0     98.987395
# 5776            1.0     24.0            99.0     98.987395
#
#       tiempo de interacción  mini juego  número de interacción  \
# 5713              19.303690         3.0                    1.0
# 5714               6.267806         3.0                    2.0
# 5715               5.766922         3.0                    3.0
# ...

# %% [markdown]
# ## Nicolas ##

# %%
#Nicolas
df_filtrado3 = df[df['Usuario'] == 3]  
df_filtrado3
# Out:
#       Administrador  Usuario  botón correcto  tiempo de interacción  \
# 0               2.0      3.0             1.0               5.399169
# 1               2.0      3.0             0.0               1.283400
# 2               2.0      3.0             1.0               2.700226
# 3               2.0      3.0             0.0               3.050262
# 4               2.0      3.0             0.0               4.750256
# ...             ...      ...             ...                    ...
# 4321            1.0      3.0            99.0              99.000000
# 4322            1.0      3.0            99.0              99.000000
# 4323            1.0      3.0             1.0               0.983153
# 4324            1.0      3.0            99.0              99.000000
# 4325            1.0      3.0            99.0              99.000000
#
#       mini juego  número de interacción  color presionado  dificultad  Juego  \
# ...

# %%
sns.pairplot(df_filtrado3)

# %%
Corr_Factors3 =df_filtrado3.corr()
Corr_Factors3
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador               1.000000      NaN       -0.032034
# Usuario                          NaN      NaN             NaN
# botón correcto             -0.032034      NaN        1.000000
# tiempo de interacción       0.074209      NaN        0.849406
# mini juego                 -0.023071      NaN        0.539327
# número de interacción      -0.016966      NaN        0.980337
# color presionado           -0.028521      NaN        0.999286
# dificultad                 -0.537313      NaN        0.009011
# Juego                       0.237799      NaN       -0.015579
# auto push                   0.034694      NaN       -0.041377
# tiempo de lección           0.042443      NaN        0.626699
# tiempo de sesión            0.003690      NaN        0.291264
#
#                        tiempo de interacción  mini juego  \
# Administrador                       0.074209   -0.023071
# ...

# %%
Corr_Factors33 = abs(Corr_Factors3)
Corr_Factors33
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador               1.000000      NaN        0.032034
# Usuario                          NaN      NaN             NaN
# botón correcto              0.032034      NaN        1.000000
# tiempo de interacción       0.074209      NaN        0.849406
# mini juego                  0.023071      NaN        0.539327
# número de interacción       0.016966      NaN        0.980337
# color presionado            0.028521      NaN        0.999286
# dificultad                  0.537313      NaN        0.009011
# Juego                       0.237799      NaN        0.015579
# auto push                   0.034694      NaN        0.041377
# tiempo de lección           0.042443      NaN        0.626699
# tiempo de sesión            0.003690      NaN        0.291264
#
#                        tiempo de interacción  mini juego  \
# Administrador                       0.074209    0.023071
# ...

# %%
Heat_Map = sns.heatmap(Corr_Factors33, cmap="Reds", annot=True, fmt=".2f")

# %% [markdown]
# ### Modelo de regresion simple ###

# %%
sns.scatterplot(x="color presionado", y="tiempo de interacción", color = "blue", data=df_filtrado3)
# Out:
# <Axes: xlabel='color presionado', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado3[['color presionado']]
Var_Dep= df_filtrado3['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Nicolas=model.score(Vars_Indep,Var_Dep)
coef_Deter_Nicolas
# Out:
# 0.718949654259092

# %%
coef_Correl_Nicolas=np.sqrt(coef_Deter_Nicolas)
coef_Correl_Nicolas
# Out:
# np.float64(0.8479089893727345)

# %% [markdown]
# ### Modelo de regresion multiple ###

# %%
sns.scatterplot(x='botón correcto', y='tiempo de interacción', color="blue", data=df_filtrado3)
sns.scatterplot(x='número de interacción', y='tiempo de interacción', color="red", data=df_filtrado3)
sns.scatterplot(x='color presionado', y='tiempo de interacción', color="yellow", data=df_filtrado3)
# Out:
# <Axes: xlabel='botón correcto', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado3[['botón correcto', 'número de interacción','color presionado']]
Var_Dep= df_filtrado3['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Nicolas=model.score(Vars_Indep,Var_Dep)
coef_Deter_Nicolas
# Out:
# 0.7261693654875385

# %%
coef_Correl_Nicolas=np.sqrt(coef_Deter_Nicolas)
coef_Correl_Nicolas
# Out:
# np.float64(0.8521557166900534)

# %%
#Predecimos los valores de total de boton correcto a partir de las variables: 'número de interacción', 'tiempo de interacción','tiempo de lección'
y_pred= model.predict(X=df_filtrado3[['botón correcto', 'número de interacción','color presionado']])
y_pred
# Out:
# array([ 8.60851604,  9.86274097, 10.76335815,  9.87168426, 10.2338057 ,
#        10.59592715, 10.9580486 , 11.85866578, 11.68229149, 10.61381373,
#        12.40653439, 14.73775079, 99.0148991 ,  7.3547207 ,  8.97063749,
#        10.22486242, 11.84077921,  8.80320649, 10.41912328, 11.49654434,
#        99.0148991 ,  9.50061952, 11.11653631, 10.04805855, 10.58698386,
#        12.20290066, 11.13442289, 99.0148991 , 10.75441487,  9.86274097,
#         9.33275894, 11.1254796 ,  9.51850609,  9.88062754, 10.9580486 ,
#        10.60487044, 11.68229149, 12.04441294, 12.40653439, 12.59185197,
#        99.0148991 ,  8.0700203 ,  8.43214175,  8.7942632 ,  9.15638465,
#        10.77230144, 10.41912328, 11.67334821, 13.289265  , 13.65138645,
#        99.0148991 ,  8.78531991,  9.6859371 , 10.22486242, 10.58698386,
#        10.94910531,  9.88062754, 10.24274899, 11.85866578, 11.68229149,
#        13.29820829, 12.22973052, 14.02245118, 99.0148991 ,  8.0700203 ,
# ...

# %%
df_filtrado3.insert(3, 'Predicciones', y_pred)
df_filtrado3
# Out:
#       Administrador  Usuario  botón correcto  Predicciones  \
# 0               2.0      3.0             1.0      8.608516
# 1               2.0      3.0             0.0      9.862741
# 2               2.0      3.0             1.0     10.763358
# 3               2.0      3.0             0.0      9.871684
# 4               2.0      3.0             0.0     10.233806
# ...             ...      ...             ...           ...
# 4321            1.0      3.0            99.0     99.014899
# 4322            1.0      3.0            99.0     99.014899
# 4323            1.0      3.0             1.0     10.754415
# 4324            1.0      3.0            99.0     99.014899
# 4325            1.0      3.0            99.0     99.014899
#
#       tiempo de interacción  mini juego  número de interacción  \
# 0                  5.399169         9.0                    1.0
# 1                  1.283400         9.0                    2.0
# 2                  2.700226         9.0                    3.0
# ...

# %% [markdown]
# ## Rene ##

# %%
#Rene
df_filtrado4 = df[df['Usuario'] == 27]  
df_filtrado4
# Out:
#       Administrador  Usuario  botón correcto  tiempo de interacción  \
# 2549            1.0     27.0             1.0              29.307090
# 2550            1.0     27.0             1.0              27.907880
# 2551            1.0     27.0             0.0              19.051010
# 2552            1.0     27.0             1.0              16.306860
# 2553            1.0     27.0             0.0               9.367180
# 2554            1.0     27.0             0.0               9.383972
# 2555            1.0     27.0             0.0              10.959300
# 2556            1.0     27.0             0.0              11.343060
# 2557            1.0     27.0             0.0              12.142600
# 2558            1.0     27.0             0.0              12.859410
# 2559            1.0     27.0             0.0              19.192930
# 2560            1.0     27.0             0.0              19.326270
# 2561            1.0     27.0             0.0              19.943110
# ...

# %%
sns.pairplot(df_filtrado4)

# %%
Corr_Factors4 =df_filtrado4.corr()
Corr_Factors4
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.879832
# mini juego                       NaN      NaN        0.689572
# número de interacción            NaN      NaN        0.976680
# color presionado                 NaN      NaN        0.999110
# dificultad                       NaN      NaN             NaN
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.679728
# tiempo de sesión                 NaN      NaN        0.682316
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Corr_Factors44 = abs(Corr_Factors4)
Corr_Factors44
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.879832
# mini juego                       NaN      NaN        0.689572
# número de interacción            NaN      NaN        0.976680
# color presionado                 NaN      NaN        0.999110
# dificultad                       NaN      NaN             NaN
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.679728
# tiempo de sesión                 NaN      NaN        0.682316
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Heat_Map = sns.heatmap(Corr_Factors44, cmap="Purples", annot=True, fmt=".2f")

# %% [markdown]
# ### Modelo de regresion simple ###

# %%
sns.scatterplot(x="color presionado", y="tiempo de interacción", color = "blue", data=df_filtrado4)
# Out:
# <Axes: xlabel='color presionado', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado4[['color presionado']]
Var_Dep= df_filtrado4['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Rene=model.score(Vars_Indep,Var_Dep)
coef_Deter_Rene
# Out:
# 0.7603262434611102

# %%
coef_Correl_Rene=np.sqrt(coef_Deter_Rene)
coef_Correl_Rene
# Out:
# np.float64(0.8719668820896297)

# %% [markdown]
# ### Modelo de regresion multiple ###

# %%
sns.scatterplot(x='botón correcto', y='tiempo de interacción', color="blue", data=df_filtrado3)
sns.scatterplot(x='número de interacción', y='tiempo de interacción', color="red", data=df_filtrado3)
sns.scatterplot(x='color presionado', y='tiempo de interacción', color="yellow", data=df_filtrado3)
# Out:
# <Axes: xlabel='botón correcto', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado4[['botón correcto', 'número de interacción','color presionado']]
Var_Dep= df_filtrado4['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Rene=model.score(Vars_Indep,Var_Dep)
coef_Deter_Rene
# Out:
# 0.8347855215948432

# %%
coef_Correl_Rene=np.sqrt(coef_Deter_Rene)
coef_Correl_Rene
# Out:
# np.float64(0.9136659792259112)

# %%
#Predecimos los valores de total de boton correcto a partir de las variables: 'número de interacción', 'tiempo de interacción','tiempo de lección'
y_pred= model.predict(X=df_filtrado4[['botón correcto', 'número de interacción','color presionado']])
y_pred
# Out:
# array([29.29144226, 34.20640487, 29.10753031, 26.87022112, 24.63236472,
#        29.54732733, 28.74025362, 27.93317991, 27.12610619, 26.31903248,
#        25.51195877, 16.12183056, 15.31475685, 24.52152031, 22.28366391,
#        18.61557203, 17.80849832, 14.14040644, 13.33333273, 18.24829534,
#        13.14996799, 98.99797576, 98.99797576, 29.29144226, 32.77562219,
#        31.96854847, 31.16147476, 30.35440105, 29.54732733, 33.03205447,
#        19.35012541, 18.5430517 , 22.02777883, 25.51195877, 24.70488505,
#        23.89781134, 23.09073763, 22.28366391, 25.76839104, 12.08646199,
#        11.27938828, 14.76411541, 98.99797576, 98.99797576])

# %%
df_filtrado4.insert(3, 'Predicciones', y_pred)
df_filtrado4
# Out:
#       Administrador  Usuario  botón correcto  Predicciones  \
# 2549            1.0     27.0             1.0     29.291442
# 2550            1.0     27.0             1.0     34.206405
# 2551            1.0     27.0             0.0     29.107530
# 2552            1.0     27.0             1.0     26.870221
# 2553            1.0     27.0             0.0     24.632365
# 2554            1.0     27.0             0.0     29.547327
# 2555            1.0     27.0             0.0     28.740254
# 2556            1.0     27.0             0.0     27.933180
# 2557            1.0     27.0             0.0     27.126106
# 2558            1.0     27.0             0.0     26.319032
# 2559            1.0     27.0             0.0     25.511959
# 2560            1.0     27.0             0.0     16.121831
# 2561            1.0     27.0             0.0     15.314757
# 2562            1.0     27.0             1.0     24.521520
# 2563            1.0     27.0             0.0     22.283664
# ...

# %% [markdown]
# ## Sergio Angel ##

# %%
#Sergio Angel
df_filtrado5 = df[df['Usuario'] == 8]  
df_filtrado5
# Out:
#       Administrador  Usuario  botón correcto  tiempo de interacción  \
# 679             5.0      8.0             1.0               2.946720
# 680             5.0      8.0             1.0               2.066744
# 681             5.0      8.0             1.0               2.600328
# 682             5.0      8.0             1.0               3.249712
# 683             5.0      8.0            99.0              99.000000
# ...             ...      ...             ...                    ...
# 2373            5.0      8.0             1.0               3.250430
# 2374            5.0      8.0             1.0               3.315942
# 2375            5.0      8.0             1.0               2.516372
# 2376            5.0      8.0            99.0              99.000000
# 2377            5.0      8.0            99.0              99.000000
#
#       mini juego  número de interacción  color presionado  dificultad  Juego  \
# ...

# %%
sns.pairplot(df_filtrado5)

# %%
Corr_Factors5 =df_filtrado5.corr()
Corr_Factors5
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.967632
# mini juego                       NaN      NaN        0.337287
# número de interacción            NaN      NaN        0.996025
# color presionado                 NaN      NaN        0.999578
# dificultad                       NaN      NaN        0.013924
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.642902
# tiempo de sesión                 NaN      NaN        0.243650
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Corr_Factors55 = abs(Corr_Factors5)
Corr_Factors55
# Out:
#                        Administrador  Usuario  botón correcto  \
# Administrador                    NaN      NaN             NaN
# Usuario                          NaN      NaN             NaN
# botón correcto                   NaN      NaN        1.000000
# tiempo de interacción            NaN      NaN        0.967632
# mini juego                       NaN      NaN        0.337287
# número de interacción            NaN      NaN        0.996025
# color presionado                 NaN      NaN        0.999578
# dificultad                       NaN      NaN        0.013924
# Juego                            NaN      NaN             NaN
# auto push                        NaN      NaN             NaN
# tiempo de lección                NaN      NaN        0.642902
# tiempo de sesión                 NaN      NaN        0.243650
#
#                        tiempo de interacción  mini juego  \
# Administrador                            NaN         NaN
# ...

# %%
Heat_Map = sns.heatmap(Corr_Factors55, cmap="Greens", annot=True, fmt=".2f")

# %% [markdown]
# ## Modelo de regresion simple ##

# %%
sns.scatterplot(x="color presionado", y="tiempo de interacción", color = "blue", data=df_filtrado5)
# Out:
# <Axes: xlabel='color presionado', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado5[['color presionado']]
Var_Dep= df_filtrado5['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Coeficiente de determinacion
coef_Deter_Sergio=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter_Sergio
# Out:
# 0.9357466041432032

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl_Sergio=np.sqrt(coef_Deter_Sergio)
coef_Correl_Sergio
# Out:
# np.float64(0.9673399630653141)

# %% [markdown]
# ## Modelo de regresion multiple ##

# %%
sns.scatterplot(x='botón correcto', y='tiempo de interacción', color="blue", data=df_filtrado5)
sns.scatterplot(x='número de interacción', y='tiempo de interacción', color="red", data=df_filtrado5)
sns.scatterplot(x='color presionado', y='tiempo de interacción', color="yellow", data=df_filtrado5)
# Out:
# <Axes: xlabel='botón correcto', ylabel='tiempo de interacción'>

# %%
Vars_Indep= df_filtrado5[['botón correcto', 'número de interacción','color presionado']]
Var_Dep= df_filtrado5['tiempo de interacción']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
coef_Deter_Sergio = model.score(Vars_Indep,Var_Dep)
coef_Deter_Sergio
# Out:
# 0.9422953208959974

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl_Sergio=np.sqrt(coef_Deter_Sergio)
coef_Correl_Sergio
# Out:
# np.float64(0.9707189711219192)

# %%
#Predecimos los valores de total de boton correcto a partir de las variables: 'número de interacción', 'tiempo de interacción','tiempo de lección'
y_pred= model.predict(X=df_filtrado5[['botón correcto', 'número de interacción','color presionado']])
y_pred
# Out:
# array([ 4.15650475,  4.85299019,  5.80701926,  6.5035047 , 98.98149177,
#         3.89896112,  5.02468594,  5.72117139,  6.5035047 , 98.98149177,
#         4.07065687,  4.93883807,  5.72117139,  6.5035047 , 98.98149177,
#         3.89896112,  5.00848511,  5.80701926,  6.58935258,  7.54338165,
#        98.98149177,  3.984809  ,  4.93883807,  5.63532351,  6.58935258,
#        98.98149177,  3.89896112,  4.93883807,  5.63532351,  6.67520046,
#         7.45753378, 98.98149177,  3.89896112,  5.02468594,  5.89286714,
#         6.57315175,  7.44133294,  8.30951414,  9.19389617,  9.97622948,
#        98.98149177,  3.984809  ,  4.93883807,  5.72117139,  6.76104833,
#         7.54338165,  8.39536201,  9.26354321, 10.1317244 , 10.93025856,
#        11.88428763, 12.8383167 , 98.98149177,  4.15650475,  4.83678936,
#         5.80701926,  6.76104833,  7.44133294,  8.41156285,  9.17769533,
#         9.97622948, 98.98149177,  4.07065687,  4.76714231,  5.70497055,
# ...

# %%
df_filtrado5.insert(3, 'Predicciones', y_pred)
df_filtrado5
# Out:
#       Administrador  Usuario  botón correcto  Predicciones  \
# 679             5.0      8.0             1.0      4.156505
# 680             5.0      8.0             1.0      4.852990
# 681             5.0      8.0             1.0      5.807019
# 682             5.0      8.0             1.0      6.503505
# 683             5.0      8.0            99.0     98.981492
# ...             ...      ...             ...           ...
# 2373            5.0      8.0             1.0      5.807019
# 2374            5.0      8.0             1.0      6.503505
# 2375            5.0      8.0             1.0      7.371686
# 2376            5.0      8.0            99.0     98.981492
# 2377            5.0      8.0            99.0     98.981492
#
#       tiempo de interacción  mini juego  número de interacción  \
# 679                2.946720         9.0                    1.0
# 680                2.066744         9.0                    2.0
# 681                2.600328         9.0                    3.0
# ...
